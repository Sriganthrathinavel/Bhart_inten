# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/Bhart/Tesla.csv - Tesla.csv.csv" , parse_dates=True , index_col="Date")
df.head()
# Out:
#                  Open   High        Low      Close    Volume  Adj Close
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
print(df.shape)
df.info()
# Out:
# (1692, 6)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1692 entries, 2010-06-29 to 2017-03-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5 KB

# %%
#Data Visualization
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df["Open"].plot(figsize=(16,8) , color='red')
plt.title("Open Tesla Stock Price History")
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD', fontsize = 18)
# Out:
# Text(0, 0.5, 'Close Price USD')

# %%
print(np.sort(df['Open']), "This is the Sorted data of Open Share Price")
plt.figure(figsize=(5,5))
plt.bar(list(np.sort(df['Open'].value_counts().keys())), list(np.sort(df['Open'].value_counts())))
plt.title("Sorted Open Share Price Graph")
plt.xlabel("Price of Open Share")
plt.ylabel("Frequency")
# Out:
# [ 16.139999  16.4       17.389999 ... 282.98999  284.01001  287.670013] This is the Sorted data of Open Share Price
# Text(0, 0.5, 'Frequency')

# %%
#Data Preprocessing
df.isna().any()
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Volume       False
# Adj Close    False
# dtype: bool

# %%
dataset = df["Open"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (1692, 1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data)

# %%
# 75% to Train , 25% to Test
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 1269 Test Size : 423

# %%
train_data.shape,test_data.shape
# Out:
# ((1269, 1), (483, 1))

# %%
#Creating training set
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((1209, 60, 1), (1209,))

# %%
#Building LSTM Model
model =Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64, return_sequences= False))
model.add(Dense(32))
model.add(Dense(16))
model.add(Dense(1))


model.compile(optimizer = 'adam', loss = 'mse' , metrics="mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor='loss', patience=10 , restore_best_weights=True)]
history = model.fit(x_train, y_train, epochs = 100, batch_size = 32 , callbacks = callbacks )
# Out:
# Epoch 1/100
# 38/38 [==============================] - 12s 11ms/step - loss: 0.0235 - mean_absolute_error: 0.0905
# Epoch 2/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0226
# Epoch 3/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 4/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0011 - mean_absolute_error: 0.0206
# Epoch 5/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 6/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0010 - mean_absolute_error: 0.0199
# Epoch 7/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0210
# Epoch 8/100
# 38/38 [==============================] - 0s 8ms/step - loss: 8.8922e-04 - mean_absolute_error: 0.0189
# Epoch 9/100
# 38/38 [==============================] - 0s 8ms/step - loss: 9.3227e-04 - mean_absolute_error: 0.0195
# Epoch 10/100
# 38/38 [==============================] - 0s 8ms/step - loss: 8.2791e-04 - mean_absolute_error: 0.0184
# Epoch 11/100
# 38/38 [==============================] - 0s 8ms/step - loss: 9.2185e-04 - mean_absolute_error: 0.0195
# Epoch 12/100
# 38/38 [==============================] - 0s 8ms/step - loss: 8.8567e-04 - mean_absolute_error: 0.0190
# Epoch 13/100
# 38/38 [==============================] - 0s 9ms/step - loss: 8.3814e-04 - mean_absolute_error: 0.0183
# Epoch 14/100
# 38/38 [==============================] - 0s 12ms/step - loss: 9.0485e-04 - mean_absolute_error: 0.0196
# Epoch 15/100
# 38/38 [==============================] - 0s 11ms/step - loss: 7.2709e-04 - mean_absolute_error: 0.0173
# Epoch 16/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.0098e-04 - mean_absolute_error: 0.0171
# Epoch 17/100
# 38/38 [==============================] - 1s 19ms/step - loss: 8.1291e-04 - mean_absolute_error: 0.0187
# Epoch 18/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.9705e-04 - mean_absolute_error: 0.0185
# Epoch 19/100
# 38/38 [==============================] - 1s 24ms/step - loss: 7.6183e-04 - mean_absolute_error: 0.0179
# Epoch 20/100
# 38/38 [==============================] - 1s 17ms/step - loss: 7.3381e-04 - mean_absolute_error: 0.0179
# Epoch 21/100
# 38/38 [==============================] - 1s 16ms/step - loss: 6.4656e-04 - mean_absolute_error: 0.0164
# Epoch 22/100
# 38/38 [==============================] - 1s 16ms/step - loss: 6.4055e-04 - mean_absolute_error: 0.0161
# Epoch 23/100
# 38/38 [==============================] - 1s 16ms/step - loss: 6.9675e-04 - mean_absolute_error: 0.0172
# Epoch 24/100
# 38/38 [==============================] - 1s 14ms/step - loss: 7.4953e-04 - mean_absolute_error: 0.0173
# Epoch 25/100
# 38/38 [==============================] - 0s 10ms/step - loss: 6.1680e-04 - mean_absolute_error: 0.0160
# Epoch 26/100
# 38/38 [==============================] - 0s 8ms/step - loss: 6.2934e-04 - mean_absolute_error: 0.0162
# Epoch 27/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.6838e-04 - mean_absolute_error: 0.0149
# Epoch 28/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.8635e-04 - mean_absolute_error: 0.0156
# Epoch 29/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.9303e-04 - mean_absolute_error: 0.0157
# Epoch 30/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.6616e-04 - mean_absolute_error: 0.0149
# Epoch 31/100
# 38/38 [==============================] - 0s 8ms/step - loss: 8.1623e-04 - mean_absolute_error: 0.0190
# Epoch 32/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.5672e-04 - mean_absolute_error: 0.0147
# Epoch 33/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.1712e-04 - mean_absolute_error: 0.0140
# Epoch 34/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.4345e-04 - mean_absolute_error: 0.0146
# Epoch 35/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.1648e-04 - mean_absolute_error: 0.0139
# Epoch 36/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.7611e-04 - mean_absolute_error: 0.0136
# Epoch 37/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.1786e-04 - mean_absolute_error: 0.0148
# Epoch 38/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.6384e-04 - mean_absolute_error: 0.0152
# Epoch 39/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.0539e-04 - mean_absolute_error: 0.0141
# Epoch 40/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.6551e-04 - mean_absolute_error: 0.0149
# Epoch 41/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.8897e-04 - mean_absolute_error: 0.0142
# Epoch 42/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.9324e-04 - mean_absolute_error: 0.0142
# Epoch 43/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.0984e-04 - mean_absolute_error: 0.0141
# Epoch 44/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.9918e-04 - mean_absolute_error: 0.0135
# Epoch 45/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.2557e-04 - mean_absolute_error: 0.0148
# Epoch 46/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.7388e-04 - mean_absolute_error: 0.0141
# Epoch 47/100
# 38/38 [==============================] - 1s 20ms/step - loss: 4.1915e-04 - mean_absolute_error: 0.0130
# Epoch 48/100
# 38/38 [==============================] - 1s 16ms/step - loss: 5.0745e-04 - mean_absolute_error: 0.0149
# Epoch 49/100
# 38/38 [==============================] - 1s 18ms/step - loss: 4.4672e-04 - mean_absolute_error: 0.0133
# Epoch 50/100
# 38/38 [==============================] - 1s 21ms/step - loss: 4.7745e-04 - mean_absolute_error: 0.0133
# Epoch 51/100
# 38/38 [==============================] - 1s 19ms/step - loss: 3.9415e-04 - mean_absolute_error: 0.0120
# Epoch 52/100
# 38/38 [==============================] - 1s 19ms/step - loss: 4.3581e-04 - mean_absolute_error: 0.0133
# Epoch 53/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.4733e-04 - mean_absolute_error: 0.0133
# Epoch 54/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.8237e-04 - mean_absolute_error: 0.0120
# Epoch 55/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.9384e-04 - mean_absolute_error: 0.0122
# Epoch 56/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.7468e-04 - mean_absolute_error: 0.0118
# Epoch 57/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.0467e-04 - mean_absolute_error: 0.0129
# Epoch 58/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.6975e-04 - mean_absolute_error: 0.0118
# Epoch 59/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.5220e-04 - mean_absolute_error: 0.0114
# Epoch 60/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.2419e-04 - mean_absolute_error: 0.0133
# Epoch 61/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.4643e-04 - mean_absolute_error: 0.0113
# Epoch 62/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.6865e-04 - mean_absolute_error: 0.0141
# Epoch 63/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.9476e-04 - mean_absolute_error: 0.0126
# Epoch 64/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.3169e-04 - mean_absolute_error: 0.0108
# Epoch 65/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.4450e-04 - mean_absolute_error: 0.0112
# Epoch 66/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.7775e-04 - mean_absolute_error: 0.0118
# Epoch 67/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.7365e-04 - mean_absolute_error: 0.0123
# Epoch 68/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.4261e-04 - mean_absolute_error: 0.0116
# Epoch 69/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.0772e-04 - mean_absolute_error: 0.0105
# Epoch 70/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.8081e-04 - mean_absolute_error: 0.0124
# Epoch 71/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.6166e-04 - mean_absolute_error: 0.0121
# Epoch 72/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.1828e-04 - mean_absolute_error: 0.0110
# Epoch 73/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.3836e-04 - mean_absolute_error: 0.0114
# Epoch 74/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.1019e-04 - mean_absolute_error: 0.0107
# Epoch 75/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.1221e-04 - mean_absolute_error: 0.0108
# Epoch 76/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.6822e-04 - mean_absolute_error: 0.0122
# Epoch 77/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.4933e-04 - mean_absolute_error: 0.0120
# Epoch 78/100
# 38/38 [==============================] - 0s 8ms/step - loss: 2.9031e-04 - mean_absolute_error: 0.0103
# Epoch 79/100
# 38/38 [==============================] - 0s 8ms/step - loss: 2.9734e-04 - mean_absolute_error: 0.0111
# Epoch 80/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.4241e-04 - mean_absolute_error: 0.0114
# Epoch 81/100
# 38/38 [==============================] - 0s 8ms/step - loss: 4.8036e-04 - mean_absolute_error: 0.0151
# Epoch 82/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.4749e-04 - mean_absolute_error: 0.0120
# Epoch 83/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.2702e-04 - mean_absolute_error: 0.0114
# Epoch 84/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.2369e-04 - mean_absolute_error: 0.0112
# Epoch 85/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.6492e-04 - mean_absolute_error: 0.0123
# Epoch 86/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.9966e-04 - mean_absolute_error: 0.0154
# Epoch 87/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.2163e-04 - mean_absolute_error: 0.0110
# Epoch 88/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.6846e-04 - mean_absolute_error: 0.0098
# Epoch 89/100
# 38/38 [==============================] - 1s 16ms/step - loss: 2.7588e-04 - mean_absolute_error: 0.0102
# Epoch 90/100
# 38/38 [==============================] - 1s 18ms/step - loss: 2.9154e-04 - mean_absolute_error: 0.0104
# Epoch 91/100
# 38/38 [==============================] - 1s 13ms/step - loss: 2.8975e-04 - mean_absolute_error: 0.0103
# Epoch 92/100
# 38/38 [==============================] - 1s 14ms/step - loss: 3.1151e-04 - mean_absolute_error: 0.0113
# Epoch 93/100
# 38/38 [==============================] - 1s 15ms/step - loss: 2.8780e-04 - mean_absolute_error: 0.0103
# Epoch 94/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.2682e-04 - mean_absolute_error: 0.0115
# Epoch 95/100
# 38/38 [==============================] - 1s 14ms/step - loss: 2.9024e-04 - mean_absolute_error: 0.0105
# Epoch 96/100
# 38/38 [==============================] - 1s 16ms/step - loss: 4.2601e-04 - mean_absolute_error: 0.0136
# Epoch 97/100
# 38/38 [==============================] - 1s 16ms/step - loss: 3.1269e-04 - mean_absolute_error: 0.0111
# Epoch 98/100
# 38/38 [==============================] - 1s 15ms/step - loss: 2.6926e-04 - mean_absolute_error: 0.0102

# %%
#Visualizing Performance
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
#Creating testing set
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((423, 60, 1), (423,))

# %%
#Predicting Testing data
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 14/14 [==============================] - 1s 6ms/step
# (423, 1)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.57

# %%
#Visualize Predictions with The Data
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize=(16,6))
plt.title('Tesla Open Stock Price Prediction' , fontsize=18)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Open Price' ,fontsize=18)
plt.plot(train['Open'],linewidth=3)
plt.plot(test['Open'],linewidth=3)
plt.plot(test["Predictions"],linewidth=3)
plt.legend(['Train','Test','Predictions'])
